# %%
from manim import *
config.media_width = "100%"
config.media_embed = True
render_as_image = "-s --disable_caching -v WARNING Example"
render_as_video = "-qm --disable_caching -v WARNING Example"
# Out:
# Manim Community v0.17.1

# %%
class MyScene(Scene):
    def setup(self):
        # We'll explain the NumberPlane class in Chapter 14
        self.number_plane = NumberPlane(axis_config={"include_numbers": False})
        self.add(self.number_plane)

# %%
# %%manim $render_as_image
#
# config.media_embed = True
#
# class Example(MyScene): # <--- MyScene instead Scene
#     def construct(self):
#         dot_line_group = Group()
#         for i in range(0, 7):
#             dt= Dot()
#             dt.set_y(3-i)
#             dot_line_group.add(dt)
#
#
#         gr_group = Group()
#         for i in range(0, 13):
#             gr =  dot_line_group.copy()
#             gr.set_x(6-i)
#             gr_group.add(gr)
#
#         self.add(gr_group)
#
#         pass

# %%
# %%manim $render_as_video
#
# config.media_embed = True
#
# class Example(Scene):
#     def construct(self):
#         c = Circle()
#         c.to_corner(UL)
#         self.add(c)
